# %%
import os
os.environ["DJANGO_SETTINGS_MODULE"] = "mydjango15.settings"
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
django.setup()

# %%
# pip install openpyxl
from openpyxl import load_workbook
wb = load_workbook('mydjango15-data.xlsx')
sheet = wb.active
rows = [
    [column.value for column in row]
    for row in sheet
]
rows
# Out:
# [['name', 'description', 'address', 'coordinates', 'telephone'],
#  ['이종구항아리짬뽕 오정점',
#   '거부할수없는 마력의 짬뽕맛집',
#   '대전 대덕구 한밭대로1006번길 11',
#   '36.3576682,127.4108615',
#   '0507-1357-8999'],
#  ['몽심',
#   '@_creative_mongsim  인스타그램을 꼭 확인 후 방문해주세요! 몽심은 매일매일 라인업이 조금씩 바뀌는 소규모 테이크아웃 베이커리입니다. 모든 디저트는 수제이며, 음료 테잌아웃 가능합니다.',
#   '대전 대덕구 한남로38번길 28',
#   '36.3518238,127.4249594',
#   '010-4459-1014'],
#  ['샤브쌈주머니 오정점',
#   '오정 농수산물시장 근처 오정사거리에 위치한 샤브샤브 월남쌈 전문점입니다. ',
#   '대전 대덕구 한밭대로 1048',
#   '36.358153,127.4148825',
#   '042-624-8485'],
#  ['명품진한우',
#   '대전광역시 서구 오정동 위치 오정네거리에서 한남오거리 방향으로 약 500m 고가철길 바로 우회전',
#   '대전 대덕구 한밭대로1006번길 105',
#   '36.354817,127.4144161',
#   '0507-1408-9266'],
#  ['황해면옥',
#   "안심식당은 '덜어먹기 가능한 도구 비치・제공', '위생적 수저관리' , '종사자마스크 착용'을 준수하는 곳으로 소재지 지자체의 인증을 받은 음식점 입니다.",
#   '대전 대덕구 한남로149번길 1',
#   '36.3469878,127.4143878',
#   '042-625-7798'],
#  ['구들마루 오정점',
#   '한남오거리에서 대전역 방향으로 내려오시면 철길 가기전 큰길가에 위치하고 있습니다^^',
#   '대전 대덕구 대전로 1009',
#   '36.3453158,127.4189646',
#   '042-673-8266'],
#  ['카페 양촌리',
#   '허 한의원 바로 옆 연노랑색 건물입니다. 골목길에서 바로 보이는 곳은 제빵실입니다. 제빵실 기준으로 왼쪽에는 계단이 있는 정문이, 오른쪽에는 쪽문이 있습니다!',
#   '대전 서구 괴정로22번길 6',
#   '36.3402674,127.3768314',
#   '0507-1383-5715'],
#  ['성심당 롯데백화점대전점',
#   'The Sweetest Heritage.  1956년 나눔이 시작된 그 터에서 늘 같은 마음으로 반세기를 이어온 성심당의 모습과 달콤한 케익. 매일 매일 만들어지는 프레쉬한 케익과 디저트를 롯데백화점 대전점 1층에서 만나보세요!',
#   '대전 서구 계룡로 598',
#   '36.3408418,127.3892867',
#   '042-220-4136'],
#  ['살롱드느티',
#   '테이블이 네개인 혼자 운영하는 작은 매장입니다. 간혹 자리가 없을 수 있으니 오시기전 예약 부탁드립니다. 감사합니다',
#   '대전 서구 도솔로 350-15',
#   '36.3384683,127.3855',
#   '0507-1375-0810'],
#  ['하프커피 대전신세계Art&Science점',
#   '평일 10:30 - 21:30 라스트오더 9시 / 주말 10:30 - 21:30 라스트오더 9시',
#   '대전 유성구 엑스포로 17 ',
#   '36.3781133,127.3843067',
#   '042-607-8526'],
#  ['키친205 대전신세계점',
#   '지하 1층 스위트존',
#   '대전 유성구 엑스포로 17',
#   '36.3781133,127.3843067',
#   'None'],
#  ['갓덴스시 대전신세계 Art & Science점',
#   '회전 초밥의 명가 갓덴스시 ! 명품 초밥의 정수를 갓덴스시 신세계 대전점에서 직접 경험해보세요.',
#   '대전 유성구 엑스포로 18',
#   '36.3979951,127.4031064',
#   '042-607-8737'],
#  ['스시덴고쿠 현대프리미엄아울렛대전점',
#   '영업시간 10:30 - 21:00',
#   '대전 유성구 테크노중앙로 124',
#   '36.4240196,127.3958129',
#   '042-332-2810'],
#  ['칸스테이크하우스 도안본점',
#   '도안 5단지 길 건너편 이철헤어커커 옆 에 위치해 있습니다.',
#   '대전 유성구 봉명서로 17-11',
#   '36.3440092,127.3410812',
#   '0507-1311-5284'],
#  ['다디',
#   '1층 전용주차장/2층이 홀입니다. 이탈리안 카페 & 비스트로 다디입니다. 오시는길은) 신탄진 이엘치과에서 보훈병원 방면으로 첫번째 사거리 지나자마자 좌측으로 위치해 있습니다.',
#   '대전 대덕구 신탄진동로 23',
#   '36.4499081,127.4314177',
#   '0507-1437-1152'],
#  ['행복유부초밥 대전은행점',
#   '스카이로드에서 은행교 쪽으로 조금만 걸어오시면 됩니다!',
#   '대전 중구 중앙로170번길 29',
#   '36.3283832,127.4292683',
#   '042-252-6655'],
#  ['플라잉팬',
#   '대전 성심당에서 운영하는 이탈리안 레스토랑, 플라잉팬에서는 편안한 비즈니스 미팅과 테마에 맞는 파티를 도와드립니다. 나무 장작으로 직접 굽는 화덕피자와 만족도 높은 디너 코스, 파스타, 스테이크로 프라이빗한 공간에서 특별하고  품격있는 시간을 성심껏 준비합니다.',
#   '대전 중구 대종로 480',
#   '36.3275153,127.4268243',
#   '042-220-4126'],
#  ['연이자카야 본점',
#   '연이자카야 연어초밥과 일본식돈까스가 맛있는 은행동맛집',
#   '대전 중구 대종로480번길 53',
#   '36.3284316,127.429405',
#   '0507-1351-7648'],
#  ['카페디아로마',
#   '은행동 성심당 본점 앞골목 에스닷(구대전문구센터)문구 옆 건물 2층에 있어요~ 대전 지하철 1호선 중앙로역 2번 출구에서 약 2분 소요. 성심당 주변에 오셔서 전화주시면 자세히 설명하겠습니다.',
#   '대전 중구 중교로73번길 14',
#   '36.3272751,127.4274854',
#   '0507-1305-8262']]

# %%
column_names = rows[0]
column_names
# Out:
# ['name', 'description', 'address', 'coordinates', 'telephone']

# %%
row_list = []

for row in rows[1:]:
    # row [0] is None:
        #break
    row_dict = dict(zip(column_names, row))
    latitude, longitude = row_dict["coordinates"].split(",")
    row_dict["latitude"] = latitude
    row_dict["longitude"] = longitude
    del row_dict["coordinates"]
    row_list.append(row_dict)
    
row_list
# Out:
# [{'name': '이종구항아리짬뽕 오정점',
#   'description': '거부할수없는 마력의 짬뽕맛집',
#   'address': '대전 대덕구 한밭대로1006번길 11',
#   'telephone': '0507-1357-8999',
#   'latitude': '36.3576682',
#   'longitude': '127.4108615'},
#  {'name': '몽심',
#   'description': '@_creative_mongsim  인스타그램을 꼭 확인 후 방문해주세요! 몽심은 매일매일 라인업이 조금씩 바뀌는 소규모 테이크아웃 베이커리입니다. 모든 디저트는 수제이며, 음료 테잌아웃 가능합니다.',
#   'address': '대전 대덕구 한남로38번길 28',
#   'telephone': '010-4459-1014',
#   'latitude': '36.3518238',
#   'longitude': '127.4249594'},
#  {'name': '샤브쌈주머니 오정점',
#   'description': '오정 농수산물시장 근처 오정사거리에 위치한 샤브샤브 월남쌈 전문점입니다. ',
#   'address': '대전 대덕구 한밭대로 1048',
#   'telephone': '042-624-8485',
#   'latitude': '36.358153',
#   'longitude': '127.4148825'},
#  {'name': '명품진한우',
#   'description': '대전광역시 서구 오정동 위치 오정네거리에서 한남오거리 방향으로 약 500m 고가철길 바로 우회전',
#   'address': '대전 대덕구 한밭대로1006번길 105',
#   'telephone': '0507-1408-9266',
#   'latitude': '36.354817',
#   'longitude': '127.4144161'},
#  {'name': '황해면옥',
#   'description': "안심식당은 '덜어먹기 가능한 도구 비치・제공', '위생적 수저관리' , '종사자마스크 착용'을 준수하는 곳으로 소재지 지자체의 인증을 받은 음식점 입니다.",
#   'address': '대전 대덕구 한남로149번길 1',
#   'telephone': '042-625-7798',
#   'latitude': '36.3469878',
#   'longitude': '127.4143878'},
#  {'name': '구들마루 오정점',
#   'description': '한남오거리에서 대전역 방향으로 내려오시면 철길 가기전 큰길가에 위치하고 있습니다^^',
#   'address': '대전 대덕구 대전로 1009',
#   'telephone': '042-673-8266',
#   'latitude': '36.3453158',
#   'longitude': '127.4189646'},
#  {'name': '카페 양촌리',
#   'description': '허 한의원 바로 옆 연노랑색 건물입니다. 골목길에서 바로 보이는 곳은 제빵실입니다. 제빵실 기준으로 왼쪽에는 계단이 있는 정문이, 오른쪽에는 쪽문이 있습니다!',
#   'address': '대전 서구 괴정로22번길 6',
#   'telephone': '0507-1383-5715',
#   'latitude': '36.3402674',
#   'longitude': '127.3768314'},
#  {'name': '성심당 롯데백화점대전점',
#   'description': 'The Sweetest Heritage.  1956년 나눔이 시작된 그 터에서 늘 같은 마음으로 반세기를 이어온 성심당의 모습과 달콤한 케익. 매일 매일 만들어지는 프레쉬한 케익과 디저트를 롯데백화점 대전점 1층에서 만나보세요!',
#   'address': '대전 서구 계룡로 598',
#   'telephone': '042-220-4136',
#   'latitude': '36.3408418',
#   'longitude': '127.3892867'},
#  {'name': '살롱드느티',
#   'description': '테이블이 네개인 혼자 운영하는 작은 매장입니다. 간혹 자리가 없을 수 있으니 오시기전 예약 부탁드립니다. 감사합니다',
#   'address': '대전 서구 도솔로 350-15',
#   'telephone': '0507-1375-0810',
#   'latitude': '36.3384683',
#   'longitude': '127.3855'},
#  {'name': '하프커피 대전신세계Art&Science점',
#   'description': '평일 10:30 - 21:30 라스트오더 9시 / 주말 10:30 - 21:30 라스트오더 9시',
#   'address': '대전 유성구 엑스포로 17 ',
#   'telephone': '042-607-8526',
#   'latitude': '36.3781133',
#   'longitude': '127.3843067'},
#  {'name': '키친205 대전신세계점',
#   'description': '지하 1층 스위트존',
#   'address': '대전 유성구 엑스포로 17',
#   'telephone': 'None',
#   'latitude': '36.3781133',
#   'longitude': '127.3843067'},
#  {'name': '갓덴스시 대전신세계 Art & Science점',
#   'description': '회전 초밥의 명가 갓덴스시 ! 명품 초밥의 정수를 갓덴스시 신세계 대전점에서 직접 경험해보세요.',
#   'address': '대전 유성구 엑스포로 18',
#   'telephone': '042-607-8737',
#   'latitude': '36.3979951',
#   'longitude': '127.4031064'},
#  {'name': '스시덴고쿠 현대프리미엄아울렛대전점',
#   'description': '영업시간 10:30 - 21:00',
#   'address': '대전 유성구 테크노중앙로 124',
#   'telephone': '042-332-2810',
#   'latitude': '36.4240196',
#   'longitude': '127.3958129'},
#  {'name': '칸스테이크하우스 도안본점',
#   'description': '도안 5단지 길 건너편 이철헤어커커 옆 에 위치해 있습니다.',
#   'address': '대전 유성구 봉명서로 17-11',
#   'telephone': '0507-1311-5284',
#   'latitude': '36.3440092',
#   'longitude': '127.3410812'},
#  {'name': '다디',
#   'description': '1층 전용주차장/2층이 홀입니다. 이탈리안 카페 & 비스트로 다디입니다. 오시는길은) 신탄진 이엘치과에서 보훈병원 방면으로 첫번째 사거리 지나자마자 좌측으로 위치해 있습니다.',
#   'address': '대전 대덕구 신탄진동로 23',
#   'telephone': '0507-1437-1152',
#   'latitude': '36.4499081',
#   'longitude': '127.4314177'},
#  {'name': '행복유부초밥 대전은행점',
#   'description': '스카이로드에서 은행교 쪽으로 조금만 걸어오시면 됩니다!',
#   'address': '대전 중구 중앙로170번길 29',
#   'telephone': '042-252-6655',
#   'latitude': '36.3283832',
#   'longitude': '127.4292683'},
#  {'name': '플라잉팬',
#   'description': '대전 성심당에서 운영하는 이탈리안 레스토랑, 플라잉팬에서는 편안한 비즈니스 미팅과 테마에 맞는 파티를 도와드립니다. 나무 장작으로 직접 굽는 화덕피자와 만족도 높은 디너 코스, 파스타, 스테이크로 프라이빗한 공간에서 특별하고  품격있는 시간을 성심껏 준비합니다.',
#   'address': '대전 중구 대종로 480',
#   'telephone': '042-220-4126',
#   'latitude': '36.3275153',
#   'longitude': '127.4268243'},
#  {'name': '연이자카야 본점',
#   'description': '연이자카야 연어초밥과 일본식돈까스가 맛있는 은행동맛집',
#   'address': '대전 중구 대종로480번길 53',
#   'telephone': '0507-1351-7648',
#   'latitude': '36.3284316',
#   'longitude': '127.429405'},
#  {'name': '카페디아로마',
#   'description': '은행동 성심당 본점 앞골목 에스닷(구대전문구센터)문구 옆 건물 2층에 있어요~ 대전 지하철 1호선 중앙로역 2번 출구에서 약 2분 소요. 성심당 주변에 오셔서 전화주시면 자세히 설명하겠습니다.',
#   'address': '대전 중구 중교로73번길 14',
#   'telephone': '0507-1305-8262',
#   'latitude': '36.3272751',
#   'longitude': '127.4274854'}]

# %%
from delicious.models import Shop

# %%
for row_dict in row_list:
    shop = Shop(**row_dict) # unpack -> 풀어넣기..?
    shop.save()
    print(shop)
# Out:
# Shop object (1)
# Shop object (2)
# Shop object (3)
# Shop object (4)
# Shop object (5)
# Shop object (6)
# Shop object (7)
# Shop object (8)
# Shop object (9)
# Shop object (10)
# Shop object (11)
# Shop object (12)
# Shop object (13)
# Shop object (14)
# Shop object (15)
# Shop object (16)
# Shop object (17)
# Shop object (18)
# Shop object (19)
